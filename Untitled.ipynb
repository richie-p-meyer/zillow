# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('zillow_city_month.csv')

# %%
df.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName  2000-01-31  \
# 0    102001         0    United States    country       NaN    127845.0
# 1    394913         1     New York, NY        msa        NY    222885.0
# 2    753899         2  Los Angeles, CA        msa        CA    230273.0
# 3    394463         3      Chicago, IL        msa        IL    167528.0
# 4    394514         4       Dallas, TX        msa        TX    128766.0
#
#    2000-02-29  2000-03-31  2000-04-30  2000-05-31  ...  2022-03-31  \
# 0    128190.0    128554.0    129295.0    130042.0  ...    337752.0
# 1    224217.0    225415.0    227774.0    229970.0  ...    587159.0
# 2    231075.0    232303.0    234638.0    237142.0  ...    904811.0
# 3    167923.0    168434.0    169458.0    170543.0  ...    295653.0
# 4    128869.0    128955.0    129164.0    129383.0  ...    363776.0
#
#    2022-04-30  2022-05-31  2022-06-30  2022-07-31  2022-08-31  2022-09-30  \
# ...

# %%
df[df.StateName=='CO']
# Out:
#      RegionID  SizeRank             RegionName RegionType StateName  \
# 19     394530        19             Denver, CO        msa        CO
# 79     394484        79   Colorado Springs, CO        msa        CO
# 149    394602       150       Fort Collins, CO        msa        CO
# 153    394645       154            Greeley, CO        msa        CO
# 155    394405       156            Boulder, CO        msa        CO
# 256    395007       257             Pueblo, CO        msa        CO
# 272    394639       273     Grand Junction, CO        msa        CO
# 449    753881       450   Glenwood Springs, CO        msa        CO
# 542    394547       548            Durango, CO        msa        CO
# 557    394556       563            Edwards, CO        msa        CO
# 605    394876       612           Montrose, CO        msa        CO
# 610    394437       617        Ca-¦on City, CO        msa        CO
# 786    753871       802       Breckenridge, CO        msa        CO
# ...

# %%
inv = pd.read_csv('inventory.csv')

# %%
inv.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName  2018-03-31  \
# 0    102001         0    United States    country       NaN   1424088.0
# 1    394913         1     New York, NY        msa        NY     73707.0
# 2    753899         2  Los Angeles, CA        msa        CA     21998.0
# 3    394463         3      Chicago, IL        msa        IL     38581.0
# 4    394514         4       Dallas, TX        msa        TX     24043.0
#
#    2018-04-30  2018-05-31  2018-06-30  2018-07-31  ...  2022-03-31  \
# 0   1502792.0   1594973.0   1663123.0   1711609.0  ...    714095.0
# 1     80345.0     85864.0     90067.0     91881.0  ...     44229.0
# 2     23784.0     25605.0     27109.0     28811.0  ...     14151.0
# 3     42253.0     45757.0     47492.0     48984.0  ...     22560.0
# 4     25876.0     28225.0     30490.0     32408.0  ...     14831.0
#
#    2022-04-30  2022-05-31  2022-06-30  2022-07-31  2022-08-31  2022-09-30  \
# ...
